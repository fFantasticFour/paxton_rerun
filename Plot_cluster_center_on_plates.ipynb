# %%
from scipy.constants import c
import numpy as np
from numpy.lib import recfunctions as rec
from astropy.io          import fits
from astropy.coordinates import SkyCoord, Angle, search_around_sky
from astropy             import units as u
from astropy import cosmology
from matplotlib import pyplot as plt
import pandas as pd

# %%
clusters=np.load("cut_clusters.npy")
galaxies=np.load("cut_dr14.npy")
cluster8=np.load("cluster8.npy")

# %%
from IPython.display import Image 
im = Image(filename='cluster8.jpg')
display(im)

# %%
import matplotlib.image as mpimg
# %matplotlib inline

img=mpimg.imread('cluster8_final.jpg')

fig, axs = plt.subplots(1,1,figsize=(16,16))
center_ra=150.5589
center_dec=20.5379
width=2048
x_positions=np.arange(0, width, 100)
x_labels=np.round((-x_positions+width/2)/3600*1.6+center_ra,2)
plt.xticks(x_positions, x_labels)
y_positions=np.arange(0, width, 100)
y_labels=np.round((-y_positions+width/2)/3600*1.5+center_dec,2)
plt.yticks(y_positions, y_labels)

axs.imshow(img,origin="lower")


center_ra_pix=1024
center_dec_pix=1024

ra=cluster8["MEM_RA"]
dec=cluster8["MEM_DEC"]
#ra=150.66857
#dec=20.18499
ra_pix=np.round((-ra+center_ra)*3600/1.6+width/2,0)
dec_pix=np.round((-dec+center_dec)*3600/1.5+width/2,0)

axs.scatter([center_ra_pix],[center_dec_pix],marker='X', s=200)

axs.scatter([ra_pix],[dec_pix],marker='o', s=50, alpha=1.0)

# %%
import pylab as p
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.cm as cm

# %matplotlib notebook

ra=cluster8["MEM_RA"]
dec=cluster8["MEM_DEC"]
z=cluster8["Z_MEM"]

fig=p.figure(figsize=(10,10))

ax3D=fig.add_subplot(111, projection='3d')
collection = ax3D.scatter(ra, dec, z)

ra=150.5589
dec=20.5379
z=0.3196
collection = ax3D.scatter(ra, dec, z)
p.title("Cluster ID 8 and identified galaxies in dr14")
p.show()
# Out:
# <img src="data:image/png;base64,..." width="719.95">

# %%
# Out:
# array([20.656387, 20.541743, 20.521592, 20.234953, 20.184989])
